# %%
#sum

a=5
b=3
sum=a+b
print("The sum is :",sum)
# Out:
# The sum is : 8

# %%
a=10
b=20
c=a+b
print("The sum is :",c)
# Out:
# The sum is : 30

# %%
a=10
b=5
c=a-b
print("The sub is :",c)
# Out:
# The sub is : 5

# %%
a=200
b=146
c=a-b
print("The sub is:",c)
# Out:
# The sub is: 54

# %%
a=5
b=4
c=a*b
print("The multi:",c)
# Out:
# The multi: 20

# %%
a=20
b=6
c=a*b
print("The multi is:",c)
# Out:
# The multi is: 120

# %%
a=10
b=2
c=a/b
print("The div is:",c)
# Out:
# The div is: 5.0

# %%
a=25
b=3
c=a/b
print("The div is:",c)
# Out:
# The div is: 8.333333333333334
